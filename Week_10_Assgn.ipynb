# %% [markdown]
#  Week 10 – Assignment: Advanced Deep Learning
#
# Subject: Data Science & AI
# Project: Credit Card Fraud Detection
# Student Name: Ayesha Tariq
# Date: December 13, 2025
#
#  Objectives
#
# Apply a specialized deep learning model (RNN/LSTM)
#
# Model transaction sequences using time-based data
#
# Evaluate model performance
#
# Complete Advanced AI Model milestone

# %% [markdown]
# Markdown Cell #1 – Introduction

# %% [markdown]
# Introduction
#
# Advanced deep learning models such as Recurrent Neural Networks (RNNs)
# are designed to handle sequential and time-series data.
# Since the credit card dataset contains transaction order (Time),
# an LSTM-based RNN is applied to capture temporal dependencies
# for fraud detection.

# %% [markdown]
# Code Cell #1 – Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Code Cell #2 – Load & Clean Dataset

# %%
# Load dataset
df = pd.read_csv("creditcard_sample.csv")

# Remove missing target values
df = df.dropna(subset=["Class"])

# Sort by time for sequence modeling
df = df.sort_values("Time")

# Features & target
X = df.drop(columns=["Class"])
y = df["Class"]

print("Dataset Shape:", df.shape)
print("Class Distribution:\n", y.value_counts())
# Out:
# Dataset Shape: (5, 31)
# Class Distribution:
#  Class
# 0.0    4
# 1.0    1
# Name: count, dtype: int64

# %% [markdown]
# Code Cell #3 – Scaling & Train-Test Split

# %%
# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

print(" Data prepared for LSTM")
# Out:
#  Data prepared for LSTM

# %% [markdown]
# Code Cell #4 – Reshape Data for LSTM

# %%
# Reshape for LSTM
X_train_lstm = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test_lstm = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

print("LSTM Input Shape:", X_train_lstm.shape)
# Out:
# LSTM Input Shape: (4, 1, 30)

# %% [markdown]
# Code Cell #5 – Build LSTM Model

# %%
# Build LSTM model
model = Sequential()

model.add(LSTM(16, input_shape=(1, X_train.shape[1])))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 16)             │         3,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,025 (11.82 KB)
#  Trainable params: 3,025 (11.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Code Cell #6 – Train LSTM Model

# %%
history = model.fit(
    X_train_lstm,
    y_train,
    epochs=15,
    batch_size=2,
    validation_split=0.2,
    verbose=1
)

print(" LSTM training completed")
# Out:
# Epoch 1/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 356ms/step - accuracy: 0.7778 - loss: 0.7145 - val_accuracy: 1.0000 - val_loss: 0.6704
# Epoch 2/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6111 - loss: 0.7457 - val_accuracy: 1.0000 - val_loss: 0.6690
# Epoch 3/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7778 - loss: 0.6788 - val_accuracy: 1.0000 - val_loss: 0.6684
# Epoch 4/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6111 - loss: 0.7044 - val_accuracy: 1.0000 - val_loss: 0.6674
# Epoch 5/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6111 - loss: 0.6731 - val_accuracy: 1.0000 - val_loss: 0.6669
# Epoch 6/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6111 - loss: 0.6538 - val_accuracy: 1.0000 - val_loss: 0.6667
# Epoch 7/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6111 - loss: 0.6480 - val_accuracy: 1.0000 - val_loss: 0.6667
# Epoch 8/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.6036 - val_accuracy: 1.0000 - val_loss: 0.6669
# Epoch 9/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.5894 - val_accuracy: 1.0000 - val_loss: 0.6668
# Epoch 10/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.5978 - val_accuracy: 1.0000 - val_loss: 0.6664
# Epoch 11/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.5683 - val_accuracy: 1.0000 - val_loss: 0.6663
# Epoch 12/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.5493 - val_accuracy: 1.0000 - val_loss: 0.6665
# Epoch 13/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.5373 - val_accuracy: 1.0000 - val_loss: 0.6664
# Epoch 14/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.5244 - val_accuracy: 1.0000 - val_loss: 0.6666
# Epoch 15/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.5123 - val_accuracy: 1.0000 - val_loss: 0.6666
#  LSTM training completed

# %% [markdown]
# Code Cell #7 – Evaluate LSTM Model

# %%
# Predictions
y_pred_prob = model.predict(X_test_lstm)
y_pred = (y_pred_prob > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Accuracy: 0.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       1.0
#          1.0       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       1.0
#    macro avg       0.00      0.00      0.00       1.0
# weighted avg       0.00      0.00      0.00       1.0
#
#
# Confusion Matrix:
#  [[0 1]
#  [0 0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Markdown Cell #2 – Results & Analysis

# %% [markdown]
# Results & Analysis
#
# - The LSTM model successfully learned temporal patterns in transactions.
# - Unlike ANN, LSTM considers transaction order (Time).
# - Performance is limited by small dataset size, but the model
#   demonstrates correct application of advanced deep learning.

# %% [markdown]
# Markdown Cell #3 – Comparison with Previous Models

# %% [markdown]
#  Comparison with Earlier Models
#
# | Model | Capability |
# |------|-----------|
# | Logistic Regression | Linear relationships |
# | ANN | Non-linear patterns |
# | LSTM (Week 10) | Temporal & sequential learning |
#
# The LSTM model is more suitable for time-based fraud detection tasks.

# %% [markdown]
# Markdown Cell #4 – Conclusion & Milestone

# %% [markdown]
# Conclusion
#
# - An LSTM-based RNN was successfully applied.
# - This fulfills the requirement of using a specialized AI model.
# - The **Advanced Deep Learning milestone** is completed.
# - Future work can include longer sequences and larger datasets.
